# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Data Set Aquisition.csv")
df
# Out:
#                         Timestamp    Your Good Name?  \
# 0     2016/12/11 8:42:47 AM GMT+5      Muhammad Adil
# 1     2016/12/11 8:47:34 AM GMT+5   Muhammad Saqlain
# 2     2016/12/11 8:48:59 AM GMT+5         Fazlul Haq
# 3     2016/12/11 8:53:11 AM GMT+5              Zamir
# 4     2016/12/11 9:01:31 AM GMT+5  Kaleem ullah khan
# ...                           ...                ...
# 997   2017/03/27 4:11:25 PM GMT+5               Jani
# 998   2017/03/27 4:13:55 PM GMT+5               Sana
# 999   2017/03/27 4:14:49 PM GMT+5         Hadia Hina
# 1000  2017/03/27 4:15:48 PM GMT+5        Sadia Jalil
# 1001  2017/03/27 4:19:55 PM GMT+5              ayub
#
#                                    Organization?    Last Degree?  \
# 0     kohat University of Science and Technology  BSC (CS or SE)
# 1                                           NUST    MS(CS or SE)
# 2                                          Govt   BSC (CS or SE)
# ...

# %% [markdown]
# ### Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 23 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Timestamp                                                                                          1002 non-null   object
#  1   Your Good Name?                                                                                    1002 non-null   object
#  2   Organization?                                                                                      1002 non-null   object
#  3   Last Degree?                                                                                       1002 non-null   object
# ...

# %% [markdown]
# #### Checking if there are any duplicate entries

# %%
duplicate_rows = df[df.duplicated()]
print('Number of duplicate Samples : ',len(duplicate_rows))
# Out:
# Number of duplicate Samples :  2

# %% [markdown]
# #### Removing the duplicates entries

# %%
df = df.drop_duplicates()
df.reset_index(inplace=True)
df = df.drop(['index'],axis =1)

# %%
df
# Out:
#                        Timestamp    Your Good Name?  \
# 0    2016/12/11 8:42:47 AM GMT+5      Muhammad Adil
# 1    2016/12/11 8:47:34 AM GMT+5   Muhammad Saqlain
# 2    2016/12/11 8:48:59 AM GMT+5         Fazlul Haq
# 3    2016/12/11 8:53:11 AM GMT+5              Zamir
# 4    2016/12/11 9:01:31 AM GMT+5  Kaleem ullah khan
# ..                           ...                ...
# 995  2017/03/27 4:11:25 PM GMT+5               Jani
# 996  2017/03/27 4:13:55 PM GMT+5               Sana
# 997  2017/03/27 4:14:49 PM GMT+5         Hadia Hina
# 998  2017/03/27 4:15:48 PM GMT+5        Sadia Jalil
# 999  2017/03/27 4:19:55 PM GMT+5              ayub
#
#                                   Organization?    Last Degree?  \
# 0    kohat University of Science and Technology  BSC (CS or SE)
# 1                                          NUST    MS(CS or SE)
# 2                                         Govt   BSC (CS or SE)
# 3                                    Daewoo E&C  BSC (CS or SE)
# ...

# %% [markdown]
# #### Removing non important Columns

# %%
df = df.drop(["Timestamp","Your Good Name?"],axis=1)

# %% [markdown]
# ### Label Encoding

# %%
list(df["Organization?"].value_counts().index)
# Out:
# ['kust',
#  'KUST',
#  'Kust',
#  'IIT',
#  'nust',
#  'KUST IIT',
#  'kust kohat',
#  'Iit',
#  'lums',
#  'NUST',
#  'Kust Kohat',
#  'UET',
#  'job',
#  'Preston',
#  'kohat kust',
#  'shaheen college',
#  'UoP',
#  'Nust',
#  'IIT KUST',
#  'Kust kohat',
#  'University',
#  'FVO',
#  'must',
#  'Kohat kust',
#  'Aiou',
#  'iit',
#  'Kohat university of science and technology',
#  'KUST Kohat',
#  'kust iit',
#  'kust university kpk Pakistan ',
#  'NUML',
#  'AWKUM',
#  'UoM',
#  'Kohat University Of Science And Technology',
#  'student',
#  'KUSt',
#  'Medline International',
#  'IQRA University peshawar',
#  'Gomal University',
#  'kusy',
#  'IIT(KUST)',
#  'No one',
#  'hunarmand college',
#  'University ',
#  'College',
#  'Agriculture',
#  'UOM',
#  'education',
#  'webtoniq solution',
#  'preston university',
#  'ITEC',
#  'Uet',
#  'LUMS',
#  'BUITEM',
#  'KULM',
#  'Student',
#  'FATA University',
#  'namal university',
#  'KUST HANGU',
#  'PESHAWER UNIVERSITY IIT',
# ...

# %%
def f1(x):
    l = list(df["Organization?"].value_counts().index)
    return l.index(x)
df["Organization?"] = df["Organization?"].apply(f1)

# %%
df["Last Degree?"].value_counts().index
# Out:
# Index(['BSC (CS or SE)', 'MS(CS or SE)', 'Phd (CS or SE)'], dtype='object')

# %%
def f2(x):
    l = ['BSC (CS or SE)', 'MS(CS or SE)', 'Phd (CS or SE)']
    return l.index(x)
df["Last Degree?"] = df["Last Degree?"].apply(f2)

# %%
df["Job Experience ?"].value_counts().index
# Out:
# Index(['Education', 'Software Industry', 'Other',
#        'Software Industry;Education', 'Education;Other',
#        'Software Industry;Education;Other', 'Software Industry;Other'],
#       dtype='object')

# %%
def f3(x):
    l = ['Education', 'Software Industry', 'Other',
       'Software Industry;Education', 'Education;Other',
       'Software Industry;Education;Other', 'Software Industry;Other']
    return l.index(x)
df["Job Experience ?"] = df["Job Experience ?"].apply(f3)

# %%
df
# Out:
#      Organization?  Last Degree?  Job Experience ?  \
# 0              143             0                 2
# 1                9             1                 0
# 2              175             0                 2
# 3              176             0                 2
# 4              177             1                 0
# ..             ...           ...               ...
# 995             16             1                 3
# 996              1             0                 3
# 997              1             0                 3
# 998              1             0                 3
# 999             11             0                 1
#
#      1. How Many Repository Architectural Styles have you used for a particular project?  \
# 0                                                    3
# 1                                                    5
# 2                                                    1
# 3                                                    2
# ...

# %%
y = df["Last Degree?"]
df = df.drop(["Last Degree?","Organization?","Job Experience ?"],axis=1)

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
data = scaler.fit_transform(df)

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    data, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Machine Learning Algorithms

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lg =  LogisticRegression(random_state=0)
lg.fit(X_train,y_train)

y_pred = lg.predict(X_train)
print("Training Results")

print("Training Accuracy : ",accuracy_score(y_train,y_pred))
print("Training Precision : ", precision_score(y_train,y_pred,average='micro'))
print("Training Recall : ",recall_score(y_train,y_pred,average='micro'))
print("Training F1-Score : ", f1_score(y_train,y_pred,average='micro'))
print(" ")
y_pred = lg.predict(X_test)

print("Testing Results")
print("Testing Accuracy : ",accuracy_score(y_test,y_pred))
print("Testing Precision : ", precision_score(y_test,y_pred,average='micro'))
print("Testing Recall : ",recall_score(y_test,y_pred,average='micro'))
print("Testing F1-Score : ", f1_score(y_test,y_pred,average='micro'))
# Out:
# Training Results
# Training Accuracy :  0.77625
# Training Precision :  0.77625
# Training Recall :  0.77625
# Training F1-Score :  0.7762499999999999
#
# Testing Results
# Testing Accuracy :  0.775
# Testing Precision :  0.775
# Testing Recall :  0.775
# Testing F1-Score :  0.775

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt =  DecisionTreeClassifier(random_state=0)
dt.fit(X_train,y_train)

y_pred = dt.predict(X_train)
print("Training Results")

print("Training Accuracy : ",accuracy_score(y_train,y_pred))
print("Training Precision : ", precision_score(y_train,y_pred,average='micro'))
print("Training Recall : ",recall_score(y_train,y_pred,average='micro'))
print("Training F1-Score : ", f1_score(y_train,y_pred,average='micro'))
print(" ")
y_pred = dt.predict(X_test)

print("Testing Results")
print("Testing Accuracy : ",accuracy_score(y_test,y_pred))
print("Testing Precision : ", precision_score(y_test,y_pred,average='micro'))
print("Testing Recall : ",recall_score(y_test,y_pred,average='micro'))
print("Testing F1-Score : ", f1_score(y_test,y_pred,average='micro'))
# Out:
# Training Results
# Training Accuracy :  0.995
# Training Precision :  0.995
# Training Recall :  0.995
# Training F1-Score :  0.995
#
# Testing Results
# Testing Accuracy :  0.615
# Testing Precision :  0.615
# Testing Recall :  0.615
# Testing F1-Score :  0.615

# %% [markdown]
# ### KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(X_train, y_train)

y_pred = neigh.predict(X_train)
print("Training Results")

print("Training Accuracy : ",accuracy_score(y_train,y_pred))
print("Training Precision : ", precision_score(y_train,y_pred,average='micro'))
print("Training Recall : ",recall_score(y_train,y_pred,average='micro'))
print("Training F1-Score : ", f1_score(y_train,y_pred,average='micro'))
print(" ")
y_pred = neigh.predict(X_test)

print("Testing Results")
print("Testing Accuracy : ",accuracy_score(y_test,y_pred))
print("Testing Precision : ", precision_score(y_test,y_pred,average='micro'))
print("Testing Recall : ",recall_score(y_test,y_pred,average='micro'))
print("Testing F1-Score : ", f1_score(y_test,y_pred,average='micro'))
# Out:
# Training Results
# Training Accuracy :  0.7825
# Training Precision :  0.7825
# Training Recall :  0.7825
# Training F1-Score :  0.7825
#
# Testing Results
# Testing Accuracy :  0.75
# Testing Precision :  0.75
# Testing Recall :  0.75
# Testing F1-Score :  0.75
# C:\Users\Z1948240\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# ### Plots of Classification Results

# %%
d=pd.DataFrame({"Logistic Regression":[0.77625,0.77625,0.77625,0.77625],"Decision tree classifier":[0.995,0.995,0.995,0.995],"KNN classifier":[0.7825,0.7825,0.7825,0.7825]},index=["Accuracy", "Precision", "Recall", "F1-score"])
d.plot(kind="bar",figsize=(20,7))
plt.title("Training Results",fontname="Times New Roman", size=28,fontweight="bold")
plt.xlabel("Classification Results",size=20)
# Out:
# Text(0.5, 0, 'Classification Results')

# %%
d=pd.DataFrame({"Logistic Regression":[0.775,0.775,0.775,0.775],"Decision tree classifier":[0.615,0.615,0.615,0.615],"KNN classifier":[0.75,0.75,0.75,0.75]},index=["Accuracy", "Precision", "Recall", "F1-score"])
d.plot(kind="bar",figsize=(20,7))
plt.title("Testing Results",fontname="Times New Roman", size=28,fontweight="bold")
plt.xlabel("Classification Results",size=20)
# Out:
# Text(0.5, 0, 'Classification Results')
